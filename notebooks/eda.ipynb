# %% [markdown]
# # EDA

# %%
import pandas as pd

# %%
all_df = pd.read_csv('../data/MM-Food-100K-cleaned.csv')
all_df
# Out:
#                                                image_url  \
# 0      https://file.b18a.io/7843322356500104680_44354...
# 1      https://file.b18a.io/7833227147700100732_67487...
# 2      https://file.b18a.io/7832600581600103585_26423...
# 3      https://file.b18a.io/7839056601700101188_98515...
# 4      https://file.b18a.io/7837642737500100261_17312...
# ...                                                  ...
# 99995  https://file.b18a.io/7833255010300109931_28888...
# 99996  https://file.b18a.io/7837300073200100128_71314...
# 99997  https://file.b18a.io/7832710876500109045_73393...
# 99998  https://file.b18a.io/7839064030900102356_78268...
# 99999  https://file.b18a.io/7832697331600109060_99225...
#
#        camera_or_phone_prob  food_prob  \
# 0                       0.7       0.95
# 1                       0.7       1.00
# 2                       0.8       0.95
# 3                       0.7       1.00
# 4                       0.8       0.90
# ...                     ...        ...
# 99995                   0.8       1.00
# 99996                   0.7       0.90
# 99997                   0.7       1.00
# 99998                   0.8       0.90
# 99999                   0.7       0.95
#
#                                      dish_name                  food_type  \
# 0                                fried chicken            restaurant food
# 1                                          pho            restaurant food
# 2                          pan-fried dumplings            restaurant food
# 3                                      bananas  raw vegetables and fruits
# 4                              noodle stir-fry            restaurant food
# ...                                        ...                        ...
# 99995                           spicy crawfish            restaurant food
# 99996                      fried chicken wings              homemade food
# 99997  grilled steak with fries and vegetables            restaurant food
# 99998                               fried tofu              homemade food
# 99999                    stuffed green peppers              homemade food
#
#                                              ingredients  \
# 0                         ['chicken', 'breading', 'oil']
# 1      ['noodles', 'beef', 'basil', 'lime', 'green on...
# 2                ['dumplings', 'chili oil', 'soy sauce']
# 3                                            ['bananas']
# 4          ['noodles', 'chicken', 'vegetables', 'sauce']
# ...                                                  ...
# 99995  ['crawfish', 'green peppers', 'onions', 'spices']
# 99996               ['chicken wings', 'breading', 'oil']
# 99997  ['steak', 'fries', 'broccoli', 'carrots', 'bel...
# 99998                                    ['tofu', 'oil']
# 99999  ['green peppers', 'ground meat', 'soy sauce', ...
#
#                                             portion_size  \
# 0                                    {'chicken': '300g'}
# 1      {'noodles': '200g', 'beef': '100g', 'vegetable...
# 2                  {'dumplings': '300g', 'sauce': '50g'}
# 3                  {'bananas': ' 10 pieces (about 1kg)'}
# 4      {'noodles': '300g', 'chicken': '100g', 'vegeta...
# ...                                                  ...
# 99995         {'crawfish': '500g', 'vegetables': '100g'}
# 99996                          {'chicken wings': '300g'}
# 99997  {'steak': '250g', 'fries': '150g', 'vegetables...
# 99998                                   {'tofu': '300g'}
# 99999   {'green peppers': '300g', 'ground meat': '100g'}
#
#                                      nutritional_profile       cooking_method  \
# 0      {'fat_g': 25.0, 'protein_g': 30.0, 'calories_k...               frying
# 1      {'fat_g': 15.0, 'protein_g': 25.0, 'calories_k...               boiled
# 2      {'fat_g': 15.0, 'protein_g': 20.0, 'calories_k...           pan-frying
# 3      {'fat_g': 3.0, 'protein_g': 12.0, 'calories_kc...                  raw
# 4      {'fat_g': 20.0, 'protein_g': 25.0, 'calories_k...           stir-fried
# ...                                                  ...                  ...
# 99995  {'fat_g': 20.0, 'protein_g': 40.0, 'calories_k...  boiled and seasoned
# 99996  {'fat_g': 25.0, 'protein_g': 20.0, 'calories_k...                fried
# 99997  {'fat_g': 45.0, 'protein_g': 60.0, 'calories_k...             grilling
# 99998  {'fat_g': 12.0, 'protein_g': 20.0, 'calories_k...               frying
# 99999  {'fat_g': 20.0, 'protein_g': 25.0, 'calories_k...                baked
#
#          sub_dt                        image_name
# 0      20250704  7843322356500104680_443548_.jpeg
# 1      20250702  7833227147700100732_674878_.jpeg
# 2      20250625   7832600581600103585_264234_.jpg
# 3      20250718   7839056601700101188_985151_.jpg
# 4      20250711  7837642737500100261_173129_.jpeg
# ...         ...                               ...
# 99995  20250717  7833255010300109931_288881_.jpeg
# 99996  20250716   7837300073200100128_713146_.jpg
# 99997  20250714  7832710876500109045_733930_.jpeg
# 99998  20250626  7839064030900102356_782681_.jpeg
# 99999  20250702   7832697331600109060_992251_.jpg
#
# [100000 rows x 11 columns]

# %%
all_df['food_type'].value_counts() / 100000 * 100
# Out:
# food_type
# homemade food                46.555
# restaurant food              35.461
# raw vegetables and fruits     9.357
# packaged food                 8.354
# others                        0.273
# Name: count, dtype: float64

# %%
len(all_df['cooking_method'].unique())
# Out:
# 1825

# %%
len(all_df['dish_name'].unique())
# Out:
# 18793

# %% [markdown]
# ---

# %%
train_df = pd.read_csv('../data/train/df_train_with_iron.csv')
train_df
# Out:
#                                               image_url  camera_or_phone_prob  \
# 0     https://file.b18a.io/7832973280900104501_54585...                   0.8
# 1     https://file.b18a.io/7835136777400102715_70587...                   0.7
# 2     https://file.b18a.io/7839412177600109625_80412...                   0.8
# 3     https://file.b18a.io/7836602996300103366_23419...                   0.8
# 4     https://file.b18a.io/7833047810700105394_87228...                   0.8
# ...                                                 ...                   ...
# 3995  https://file.b18a.io/7838856390000104847_87945...                   0.8
# 3996  https://file.b18a.io/7839128531500102319_18272...                   0.7
# 3997  https://file.b18a.io/7833732885600102602_18453...                   0.8
# 3998  https://file.b18a.io/7832593162900100943_94033...                   0.8
# 3999  https://file.b18a.io/7834674152800100909_63254...                   0.7
#
#       food_prob                       dish_name                  food_type  \
# 0          0.90                         oysters              homemade food
# 1          0.95                   grilled steak            restaurant food
# 2          0.95         sweet and sour potatoes              homemade food
# 3          1.00                         hot pot            restaurant food
# 4          0.95              stir-fried noodles              homemade food
# ...         ...                             ...                        ...
# 3995       0.90                        cucumber  raw vegetables and fruits
# 3996       0.90                 braised chicken              homemade food
# 3997       0.90  stir-fried meat and vegetables              homemade food
# 3998       0.90                   seafood salad              homemade food
# 3999       0.90                      cheese bun              homemade food
#
#                                             ingredients  \
# 0                                           ['oysters']
# 1     ['steak', 'broccoli', 'potato', 'tomato', 'sau...
# 2                 ['potatoes', 'green onions', 'sauce']
# 3               ['beef', 'pork', 'vegetables', 'sauce']
# 4       ['noodles', 'carrots', 'bean sprouts', 'sauce']
# ...                                                 ...
# 3995                                       ['cucumber']
# 3996       ['chicken', 'soy sauce', 'garlic', 'ginger']
# 3997                    ['meat', 'vegetables', 'sauce']
# 3998  ['shrimp', 'squid', 'lettuce', 'tomato', 'carr...
# 3999                                  ['bun', 'cheese']
#
#                                            portion_size  \
# 0                                   {'oysters': '500g'}
# 1     {'steak': '250g', 'broccoli': '50g', 'potato':...
# 2                  {'potatoes': '300g', 'sauce': '50g'}
# 3     {'beef': '300g', 'pork': '200g', 'vegetables':...
# 4             {'noodles': '300g', 'vegetables': '100g'}
# ...                                                 ...
# 3995                               {'cucumber': '300g'}
# 3996                {'chicken': '300g', 'sauce': '50g'}
# 3997             {'meat': '200g', 'vegetables': '150g'}
# 3998           {'shrimp': '100g', 'vegetables': '250g'}
# 3999                   {'bun': '150g', 'cheese': '50g'}
#
#                                     nutritional_profile cooking_method  \
# 0     {'fat_g': 5.0, 'protein_g': 20.0, 'calories_kc...            raw
# 1     {'fat_g': 30.0, 'protein_g': 50.0, 'calories_k...       grilling
# 2     {'fat_g': 10.0, 'protein_g': 5.0, 'calories_kc...     stir-fried
# 3     {'fat_g': 80.0, 'protein_g': 100.0, 'calories_...        boiling
# 4     {'fat_g': 15.0, 'protein_g': 20.0, 'calories_k...    stir-frying
# ...                                                 ...            ...
# 3995  {'fat_g': 0.1, 'protein_g': 0.7, 'calories_kca...            raw
# 3996  {'fat_g': 30.0, 'protein_g': 35.0, 'calories_k...       braising
# 3997  {'fat_g': 20.0, 'protein_g': 15.0, 'calories_k...    stir-frying
# 3998  {'fat_g': 15.0, 'protein_g': 25.0, 'calories_k...   raw/prepared
# 3999  {'fat_g': 15.0, 'protein_g': 10.0, 'calories_k...          baked
#
#         sub_dt                        image_name  Iron, Fe  Calcium, Ca  \
# 0     20250710  7832973280900104501_545859_.jpeg      0.90        160.0
# 1     20250702  7835136777400102715_705873_.jpeg      5.85        102.0
# 2     20250709   7839412177600109625_804127_.jpg      1.26         29.0
# 3     20250707  7836602996300103366_234194_.jpeg      6.93        193.0
# 4     20250713   7833047810700105394_872282_.jpg      3.70        120.0
# ...        ...                               ...       ...          ...
# 3995  20250627   7838856390000104847_879459_.jpg      0.00         48.0
# 3996  20250721  7839128531500102319_182726_.jpeg      0.12          5.0
# 3997  20250714   7833732885600102602_184531_.jpg      4.42        197.0
# 3998  20250722  7832593162900100943_940335_.jpeg      5.32        237.0
# 3999  20250626  7834674152800100909_632543_.jpeg      5.04        218.0
#
#       Vitamin C, total ascorbic acid
# 0                               0.50
# 1                              36.35
# 2                              45.80
# 3                              48.25
# 4                               8.50
# ...                              ...
# 3995                            8.40
# 3996                            0.50
# 3997                           12.95
# 3998                           45.15
# 3999                            0.30
#
# [4000 rows x 14 columns]

# %%
train_df['food_type'].value_counts()
# Out:
# food_type
# homemade food                1862
# restaurant food              1419
# raw vegetables and fruits     374
# packaged food                 334
# others                         11
# Name: count, dtype: int64

# %%
train_df['food_type'].value_counts() / 4000 * 100
# Out:
# food_type
# homemade food                46.550
# restaurant food              35.475
# raw vegetables and fruits     9.350
# packaged food                 8.350
# others                        0.275
# Name: count, dtype: float64

# %%
len(train_df['cooking_method'].unique())
# Out:
# 362

# %%
len(train_df['dish_name'].unique())
# Out:
# 2022

# %%
train_df['Iron, Fe'].describe()
# Out:
# count    4000.000000
# mean        4.001941
# std         4.225931
# min         0.000000
# 25%         1.713750
# 50%         3.360000
# 75%         5.310000
# max       152.500000
# Name: Iron, Fe, dtype: float64

# %%
train_df[['Iron, Fe', 'Calcium, Ca', 'Vitamin C, total ascorbic acid']].describe()
# Out:
#           Iron, Fe  Calcium, Ca  Vitamin C, total ascorbic acid
# count  4000.000000  4000.000000                     4000.000000
# mean      4.001941   142.554700                       20.131786
# std       4.225931   126.986913                       30.739538
# min       0.000000     0.000000                        0.000000
# 25%       1.713750    46.000000                        0.750000
# 50%       3.360000   112.000000                        9.350000
# 75%       5.310000   202.000000                       25.012500
# max     152.500000  1277.000000                      364.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(data=train_df, x='Iron, Fe', bins=30, kde=True)
plt.title('Distribution of Iron Content in Dishes')
plt.xlabel('Iron, Fe (mg)')
plt.ylabel('Number of Dishes')
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=train_df, x='Calcium, Ca', bins=30, kde=True)
plt.title('Distribution of Calcium Content in Dishes')
plt.xlabel('Calcium, Ca (mg)')
plt.ylabel('Number of Dishes')
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=train_df, x='Vitamin C, total ascorbic acid', bins=30, kde=True)
plt.title('Distribution of Vitamin C Content in Dishes')
plt.xlabel('Vitamin C, total ascorbic acid (mg)')
plt.ylabel('Number of Dishes')
plt.tight_layout()
plt.show()
