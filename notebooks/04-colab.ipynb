# %% [markdown]
# <a href="https://colab.research.google.com/github/chelseanbr/csml-final-project/blob/main/notebooks/04-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab

# %% [markdown]
# https://colab.research.google.com/github/chelseanbr/csml-final-project/blob/main/notebooks/04-colab.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from google.colab import userdata
os.environ["TOKEN"] = userdata.get('TOKEN')

# %%
# %cd /content/drive/MyDrive/csml
# %pwd
# %ls
# Out:
# /content/drive/MyDrive/csml
# csml-final-project@

# %%
# !git clone https://$TOKEN@github.com/chelseanbr/csml-final-project.git

# %%
# %cd csml-final-project
# %pwd
# %ls
# Out:
# /content/drive/.shortcut-targets-by-id/1Bs0GRccYBOB1gnenByQJJVmt166rOH5v/csml-final-project
# data/        models/     README.md  requirements.txt
# data.tar.gz  notebooks/  report/    src/

# %%
# !tar -xzvf data.tar.gz

# %%
# !pip install -q -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 83.6 MB/s eta 0:00:00

# %% [markdown]
# ---

# %%
# !git pull
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 224.80 KiB | 2.39 MiB/s, done.
# From https://github.com/chelseanbr/csml-final-project
#    288d15d..2ffbf11  main       -> origin/main
# Updating 288d15d..2ffbf11
# Fast-forward
#  notebooks/04-colab.ipynb | 301 ++++++++++-------------------------------------
#  1 file changed, 65 insertions(+), 236 deletions(-)

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git config --global user.email "chelseanbr@utexas.edu"
# !git config --global user.name "Chelsea Ramos"
# !git add --all
# !git commit -m "update"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %% [markdown]
# ---

# %%
# !python -m src.finetune demo_train
# Out:
# 2025-10-24 21:42:30.234713: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761342150.478868    3110 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761342150.509473    3110 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761342150.526559    3110 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761342150.526605    3110 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761342150.526613    3110 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761342150.526619    3110 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-24 21:42:30.533248: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# processor_config.json: 100% 68.0/68.0 [00:00<00:00, 584kB/s]
# chat_template.json: 100% 429/429 [00:00<00:00, 3.89MB/s]
# preprocessor_config.json: 100% 486/486 [00:00<00:00, 5.19MB/s]
# tokenizer_config.json: 28.2kB [00:00, 69.2MB/s]
# vocab.json: 801kB [00:00, 42.3MB/s]
# merges.txt: 466kB [00:00, 114MB/s]
# tokenizer.json: 3.55MB [00:00, 214MB/s]
# added_tokens.json: 4.74kB [00:00, 24.0MB/s]
# special_tokens_map.json: 1.07kB [00:00, 6.70MB/s]
# <frozen runpy>:128: RuntimeWarning: 'src.finetune' found in sys.modules after import of package 'src', but prior to execution of 'src.finetune'; this may result in unpredictable behaviour
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/modeling_auto.py:2284: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# config.json: 7.35kB [00:00, 34.0MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: 100% 513M/513M [00:11<00:00, 45.6MB/s]
# generation_config.json: 100% 136/136 [00:00<00:00, 1.25MB/s]
# trainable params: 3,872,256 || all params: 260,357,184 || trainable%: 1.4873
# Loaded 14 QA pairs for train_demo split
# {'loss': 8.8774, 'grad_norm': 71.43778991699219, 'learning_rate': 1e-08, 'epoch': 0.07}
# {'loss': 6.9218, 'grad_norm': 111.2095718383789, 'learning_rate': 9.285714285714286e-09, 'epoch': 0.14}
# {'loss': 1.6445, 'grad_norm': 25.76837921142578, 'learning_rate': 8.571428571428572e-09, 'epoch': 0.21}
# {'loss': 4.5162, 'grad_norm': 66.69136810302734, 'learning_rate': 7.857142857142857e-09, 'epoch': 0.29}
# {'loss': 11.516, 'grad_norm': 184.48947143554688, 'learning_rate': 7.142857142857143e-09, 'epoch': 0.36}
# {'loss': 2.5727, 'grad_norm': 21.604753494262695, 'learning_rate': 6.4285714285714295e-09, 'epoch': 0.43}
# {'loss': 4.3464, 'grad_norm': 29.542434692382812, 'learning_rate': 5.714285714285714e-09, 'epoch': 0.5}
# {'loss': 2.1588, 'grad_norm': 18.84392738342285, 'learning_rate': 5e-09, 'epoch': 0.57}
# {'loss': 2.6936, 'grad_norm': 24.980731964111328, 'learning_rate': 4.285714285714286e-09, 'epoch': 0.64}
# {'loss': 6.0874, 'grad_norm': 65.65300750732422, 'learning_rate': 3.5714285714285715e-09, 'epoch': 0.71}
# {'loss': 5.5598, 'grad_norm': 114.90715026855469, 'learning_rate': 2.857142857142857e-09, 'epoch': 0.79}
# {'loss': 3.3845, 'grad_norm': 32.42983627319336, 'learning_rate': 2.142857142857143e-09, 'epoch': 0.86}
# {'loss': 3.8312, 'grad_norm': 73.40531921386719, 'learning_rate': 1.4285714285714286e-09, 'epoch': 0.93}
# {'loss': 2.5521, 'grad_norm': 15.948486328125, 'learning_rate': 7.142857142857143e-10, 'epoch': 1.0}
# {'train_runtime': 14.4218, 'train_samples_per_second': 0.971, 'train_steps_per_second': 0.971, 'train_loss': 4.761593299252646, 'epoch': 1.0}
# 100% 14/14 [00:14<00:00,  1.03s/it]

# %%
# !python -m src.finetune val demo_train
# Out:
# 2025-10-24 21:43:53.450441: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761342233.485295    3576 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761342233.496313    3576 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761342233.522058    3576 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761342233.522093    3576 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761342233.522104    3576 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761342233.522113    3576 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-24 21:43:53.529436: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <frozen runpy>:128: RuntimeWarning: 'src.finetune' found in sys.modules after import of package 'src', but prior to execution of 'src.finetune'; this may result in unpredictable behaviour
# Loaded 3607 QA pairs for val-grader split
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/modeling_auto.py:2284: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# `torch_dtype` is deprecated! Use `dtype` instead!
#   0% 0/4 [00:00<?, ?it/s]	Processed 32 samples
# 	Questions: ['What primary cooking method was used for this dish?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What primary cooking method was used for this dish?', 'What category of food is this?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What category of food is this?', 'What category of food is this?', 'What category of food is this?', 'What primary cooking method was used for this dish?', 'What is the estimated weight of the ingredient "cream" in grams?', 'What is the general name of this dish?', 'What is the estimated weight of the ingredient "eggs" in grams?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What category of food is this?', 'What is the estimated weight of the ingredient "vegetables" in grams?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What is the estimated weight of the ingredient "bun" in grams?', 'What is the general name of this dish?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What is the estimated weight of the ingredient "steak" in grams?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What is the estimated weight of the ingredient "shrimp porridge" in grams?', 'What category of food is this?', 'What primary cooking method was used for this dish?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What is the general name of this dish?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What is the estimated weight of the ingredient "chicken" in grams?', 'What primary cooking method was used for this dish?', 'What is the estimated weight of the ingredient "fish" in grams?', 'What is the estimated weight of the ingredient "sponge cake" in grams?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.']
# 	Responses: ['The primary cooking method used for this dish is grilling.', '{\n    "calorie": "100",\n    "fat": "10g",\n    "protein": "10g",\n    "carbohydrates', 'The primary cooking method used for this dish is not explicitly mentioned in the image, but it is likely that the fruit is preserved in some form of jelly or jelly', 'This is a fruit.', '{\n    "calorie": "140",\n    "fat": "15g",\n    "protein": "1g",\n    "carbohydrate":', 'This is a vegetable dish.', 'This is a food item that is not a vegetarian, vegan, or gluten-free item.', 'Seafood.', 'The primary cooking method used for this dish is grilling.', 'The estimated weight of the ingredient "cream" in grams is not provided in the text.', 'The dish is called "noodles soup."', '200 grams', '{\n    "calorie": "140",\n    "fat": "10g",\n    "protein": "1g",\n    "carbohydrates":', 'This is a snack.', '100 grams', '{\n    "total weight": "1000g",\n    "micro-nutrients": [\n        "100mg",\n        "10', '100 grams.', "It's a cherry pie.", '{\n    "calorie": "100",\n    "fat": "10g",\n    "protein": "1g",\n    "carbohydrate":', '100 grams.', '{\n    "calorie": "100",\n    "fat": "10g",\n    "protein": "1g",\n    "carbohydrate":', 'The estimated weight of the ingredient "shrimp porridge" is approximately 10 grams.', 'The food is likely a type of Chinese takeout or delivery.', 'Sautéing.', 'The total weight of the meat in the dish is approximately 1.5 grams, and the total weight of the noodles in the dish is approximately 1.', 'Potatoes.', '{\n    "total weight": "1000g",\n    "micro-nutrients": [\n        "10g",\n        "10g', 'The weight of the ingredient "chicken" is not specified in the image.', 'The primary cooking method used for this dish is grilling.', '1000.', 'The item is 100 times taller than the diameter of a quarter, and made from a mixture of butter, eggs, sugar, and butter, all', '{\n    "calorie": "100",\n    "fat": "10g",\n    "protein": "10g",\n    "carbohydrate']
# 	Answers: ['stir-frying', '{"calories_kcal":600.0,"fat_g":20.0,"protein_g":15.0,"carbs_g":80.0}', 'raw', 'raw vegetables and fruits', '{"calories_kcal":800.0,"fat_g":30.0,"protein_g":25.0,"carbs_g":100.0}', 'raw vegetables and fruits', 'homemade food', 'restaurant food', 'raw', '150g', 'beef noodle soup', '200g', '{"calories_kcal":800.0,"fat_g":30.0,"protein_g":50.0,"carbs_g":70.0}', 'packaged food', '50g', '{"total_weight_g":200.0,"iron_mg":0.22,"calcium_mg":24.0,"vitamin_C_mg":20.8}', '150g', 'watermelon', '{"calories_kcal":600.0,"fat_g":25.0,"protein_g":30.0,"carbs_g":70.0}', '200g', '{"calories_kcal":200.0,"fat_g":8.0,"protein_g":3.0,"carbs_g":30.0}', '300g', 'restaurant food', 'steamed', '{"total_weight_g":400.0,"iron_mg":3.79,"calcium_mg":94.0,"vitamin_C_mg":18.25}', 'pan-fried gnocchi', '{"total_weight_g":250.0,"iron_mg":2.8200000000000003,"calcium_mg":131.0,"vitamin_C_mg":4.45}', '200g', 'fried', '250g', ' 100g', '{"calories_kcal":150.0,"fat_g":5.0,"protein_g":3.0,"carbs_g":25.0}']
#  25% 1/4 [00:22<01:08, 22.74s/it]	Processed 64 samples
# 	Questions: ['Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What primary cooking method was used for this dish?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What is the estimated weight of the ingredient "meat" in grams?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What is the general name of this dish?', 'What is the general name of this dish?', 'What is the estimated weight of the ingredient "meat" in grams?', 'What is the estimated weight of the ingredient "cream" in grams?', 'What is the estimated weight of the ingredient "broth" in grams?', 'What is the general name of this dish?', 'What primary cooking method was used for this dish?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What primary cooking method was used for this dish?', 'What is the estimated weight of the ingredient "rice" in grams?', 'What is the estimated weight of the ingredient "sweet potato" in grams?', 'What category of food is this?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What category of food is this?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What is the estimated weight of the ingredient "noodles" in grams?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What primary cooking method was used for this dish?', 'What is the general name of this dish?', 'What primary cooking method was used for this dish?', 'What is the estimated weight of the ingredient "egg" in grams?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What is the estimated weight of the ingredient "vegetables" in grams?', 'What category of food is this?']
# 	Responses: ['1400 kilocalories and 1400 grams of macronutrients.', 'The primary cooking method used for this dish is steaming.', '{\n    "menu": {\n        "nm": "糖果",\n        "num": "1",\n        "price": "1.50', '3000 kilocalories, 100 grams of fat, 100 grams of protein, and 100 grams of', 'The weight of the ingredient "meat" is not specified in the image.', 'The total weight of the dish is 100 grams, and it contains 1000 milligrams of vitamins A, C, and E.', 'The dish is called "Korean Style Sesame Seeds."', 'The dish is called "mango rice."', '100 grams.', '100 grams', '0.015 grams.', 'The dish is likely a Chinese or Asian-style food.', 'The primary cooking method used for this dish is steaming.', '{\n    "calorie": "100",\n    "fat": "10g",\n    "protein": "10g",\n    "carbohydrate', 'The primary cooking method used for this dish is boiling.', '500 grams.', '100 grams.', 'This is a soup.', '{\n    "calorie": "100",\n    "fat": "10g",\n    "protein": "1g",\n    "carbohydrate":', '{\n    "menu": {\n        "nm": "Duck Chicken",\n        "num": "1",\n        "price": "1.99",', 'This is a type of bacon.', '{\n    "menu": {\n        "nm": "spaghetti",\n        "num": "1",\n        "unitprice": "1.25",', '3500 cal/1.2 lb/2.5 kg/3.5 oz/1.2 lb/2.5 oz/', '0.015 grams.', '955\n955\nCalories: 955\nCalories from Fat: 100\nCalories from Protein:', 'The primary cooking method used for this dish is grilling.', 'The dish is called "spaghetti" in English.', 'The primary cooking method used for this dish is steaming.', '0.03 grams, 0.025 grams, 0.01 grams, 0.005 grams, 0', '{\n    "total weight": "100 grams",\n    "microgreens": [\n        {\n            "type": "green",\n            "num_micro', '100.', 'This food is in the dairy category.']
# 	Answers: ['{"calories_kcal":250.0,"fat_g":10.0,"protein_g":5.0,"carbs_g":35.0}', 'boiled', '{"calories_kcal":102.0,"fat_g":0.2,"protein_g":0.6,"carbs_g":27.6}', '{"calories_kcal":600.0,"fat_g":25.0,"protein_g":30.0,"carbs_g":60.0}', '200g', '{"total_weight_g":300.0,"iron_mg":0.75,"calcium_mg":60.0,"vitamin_C_mg":182.7}', 'meat with dipping sauce', 'fruit with spice dip', '50g', '100g', '300g', 'chicken and broccoli with rice', 'boiling', '{"calories_kcal":250.0,"fat_g":15.0,"protein_g":20.0,"carbs_g":10.0}', 'raw', '200g', '200g', 'restaurant food', '{"calories_kcal":600.0,"fat_g":25.0,"protein_g":35.0,"carbs_g":50.0}', '{"calories_kcal":600.0,"fat_g":20.0,"protein_g":40.0,"carbs_g":60.0}', 'restaurant food', '{"calories_kcal":600.0,"fat_g":20.0,"protein_g":25.0,"carbs_g":80.0}', '{"calories_kcal":450.0,"fat_g":10.0,"protein_g":25.0,"carbs_g":70.0}', '150g', '{"calories_kcal":600.0,"fat_g":25.0,"protein_g":40.0,"carbs_g":50.0}', 'grilling', 'spaghetti', 'packaged', '50g', '{"total_weight_g":750.0,"iron_mg":10.155,"calcium_mg":634.0,"vitamin_C_mg":17.3}', '150g', 'restaurant food']
#  50% 2/4 [00:41<00:40, 20.30s/it]	Processed 96 samples
# 	Questions: ['What is the general name of this dish?', 'What is the estimated weight of the ingredient "herbs" in grams?', 'What is the estimated weight of the ingredient "tomatoes" in grams?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What is the estimated weight of the ingredient "lime" in grams?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What is the estimated weight of the ingredient "rice" in grams?', 'What primary cooking method was used for this dish?', 'What is the estimated weight of the ingredient "green onions" in grams?', 'What is the general name of this dish?', 'What is the estimated weight of the ingredient "crab" in grams?', 'What is the estimated weight of the ingredient "shrimp" in grams?', 'What is the general name of this dish?', 'What is the general name of this dish?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What is the general name of this dish?', 'What is the general name of this dish?', 'What is the estimated weight of the ingredient "sausage" in grams?', 'What is the estimated weight of the ingredient "meat" in grams?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What is the estimated weight of the ingredient "sauce" in grams?', 'What is the estimated weight of the ingredient "meat" in grams?', 'What is the estimated weight of the ingredient "noodles" in grams?', 'What is the estimated weight of the ingredient "fries" in grams?', 'What category of food is this?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What is the estimated weight of the ingredient "broth" in grams?', 'What is the estimated weight of the ingredient "sauce" in grams?']
# 	Responses: ['The dish is called "Chow Chow."', '10.', '200 grams.', '{\n    "total weight": [5, "Miscellaneous"],\n    "micro-nutrients": [3, "Calcium"]\n}', '100 grams', '{\n    "total weight": "100g",\n    "micro-nutrients": [\n        "10g",\n        "10g"', 'The top of the dish contains a large, light brown, egg-shaped object, which is likely a pancake or similar pancake-like item. The', '1000 grams.', 'The primary cooking method used for this dish is steaming.', '20.', 'Chocolate cake.', 'The crab is likely to be a type of crab, as it is cooked and has a dark, round shape.', '100 grams', 'The dish is called mochi.', 'The dish is called fries.', 'The top of a bowl of noodle soup with chopsticks in it. The soup is a light orange color and contains white noodles. The noodles are long and', 'The dish is made with sunflower oil, which is a light yellow color, and is served with a straw.', 'The dish is called "Dumplings".', '100 grams.', '1000 grams.', 'The total weight of the dish is approximately 100 grams, and the micronutrients are as follows:\n- Vitamin A: 100 mg', 'The weight of the sauce is not specified in the image.', '250,000,000,000,000,00,000,000,', '200 grams.', '100,000,000,000,000,000.', 'This is a biscuit.', 'The dish contains 1000 calories and 100 grams of protein.', '3500 1000 100 100 100 100 100 1', '{\n    "title": "Coconut Rice",\n    "subtitle": "A delicious and healthy dish that is rich in fiber, protein, and vitamins', '2500–3000 cal/1g protein, 150–200 g fat, 10–1', '1000 grams', 'The weight of the sauce is not mentioned in the image.']
# 	Answers: ['fish stew', '50g', '50g', '{"total_weight_g":260.0,"iron_mg":10.55,"calcium_mg":281.9,"vitamin_C_mg":12.05}', '200g', '{"total_weight_g":300.0,"iron_mg":4.85,"calcium_mg":171.0,"vitamin_C_mg":0.6000000000000001}', '{"total_weight_g":350.0,"iron_mg":3.26,"calcium_mg":187.0,"vitamin_C_mg":6.75}', '200g', 'stir-fried', '50g', 'chocolate cake', '400g', '100g', 'cookies', 'hamburger with fries', '{"total_weight_g":600.0,"iron_mg":3.0,"calcium_mg":143.0,"vitamin_C_mg":7.0}', 'iced coffee', 'dumplings and noodle soup', '100g', '150g', '{"total_weight_g":500.0,"iron_mg":6.11,"calcium_mg":183.0,"vitamin_C_mg":38.0}', '200g', '50g', '300g', '150g', 'packaged food', '{"calories_kcal":200.0,"fat_g":2.0,"protein_g":40.0,"carbs_g":0.0}', '{"calories_kcal":600.0,"fat_g":15.0,"protein_g":20.0,"carbs_g":85.0}', '{"total_weight_g":200.0,"iron_mg":2.12,"calcium_mg":236.0,"vitamin_C_mg":5.0}', '{"calories_kcal":77.0,"fat_g":1.1,"protein_g":3.3,"carbs_g":17.1}', '250ml', '50g']
#  75% 3/4 [01:01<00:20, 20.37s/it]	Processed 128 samples
# 	Questions: ['What category of food is this?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What primary cooking method was used for this dish?', 'What is the general name of this dish?', 'What is the estimated weight of the ingredient "ground meat" in grams?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What category of food is this?', 'What is the estimated weight of the ingredient "broth" in grams?', 'What is the general name of this dish?', 'What primary cooking method was used for this dish?', 'What is the estimated weight of the ingredient "shrimp" in grams?', 'What category of food is this?', 'What primary cooking method was used for this dish?', 'What category of food is this?', 'What is the estimated weight of the ingredient "vegetables" in grams?', 'What primary cooking method was used for this dish?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What is the estimated weight of the ingredient "patty" in grams?', 'What is the general name of this dish?', 'What is the estimated weight of the ingredient "ginger" in grams?', 'What category of food is this?', 'What primary cooking method was used for this dish?', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What is the estimated weight of the ingredient "tofu" in grams?', 'What is the estimated weight of the ingredient "clams" in grams?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'What primary cooking method was used for this dish?', 'Provide a JSON object containing the calories (in kilocalories) and macronutrients (fat, protein and carbohydrates in grams) for the entire dish.', 'Provide a JSON object containing the total weight (in grams) and micronutrients for the entire dish in milligrams.', 'What is the general name of this dish?', 'What is the general name of this dish?']
# 	Responses: ['Soup.', 'The total weight of the entire dish is 1000 grams.', 'The primary cooking method used for this dish is steaming.', 'The dish is called pasta.', '100 grams', '{\n    "calorie": "100",\n    "fat": "10g",\n    "protein": "10g",\n    "carbohydrate', 'This is a rice dish.', '200 g', 'Chinese, possibly beef, mushrooms, and vegetables.', 'The primary cooking method used for this dish is grilling.', '200 grams.', 'This is a type of food.', 'Peking duck.', 'This is a soup.', '200 grams', 'Grilling.', '3000 cal/1.25g fat, 100 g/1.25g protein, 10 g/', 'The estimated weight of the ingredient "patty" is 10 grams.', 'The dish is called "荷荷荷荷荷荷荷荷荷', '100 grams', 'This is a soup.', 'Baking.', '{\n    "total_weight": "100g",\n    "microcutrient": [\n        "10g",\n        "10g"', 'The calorie count is 350, the fat count is 10g, the protein count is 1g, and the carbohydrates count is', '500,000,000,000,000,000.', '100 grams', '{\n    "menu": {\n        "nm": "Light Cheese Cake",\n        "unitprice": "￥150",\n        "price":', 'The primary cooking method used for this dish is steaming.', '{\n    "calorie": "100",\n    "fat": "10g",\n    "protein": "10g",\n    "carbohydrates', '{\n    "title": "Banana Soup",\n    "subtitle": "A delicious and nutritious dish rich in fiber, vitamins, and minerals.",\n    "', 'The dish is called "Chicken and Sausage" in English.', 'The general name of this dish is not mentioned in the provided facts.']
# 	Answers: ['restaurant food', '{"total_weight_g":100.0,"iron_mg":0.0,"calcium_mg":154.0,"vitamin_C_mg":0.0}', 'boiled and sautéed', 'chicken noodle soup', '100g', '{"calories_kcal":30.0,"fat_g":0.2,"protein_g":0.6,"carbs_g":7.6}', 'restaurant food', '250g', 'stir-fried mixed vegetables with meat', 'fried', '300g', 'homemade food', 'stir-frying', 'homemade food', '50g', 'chilled/raw', '{"calories_kcal":200.0,"fat_g":10.0,"protein_g":5.0,"carbs_g":25.0}', '150g', 'spicy cucumber salad', '20g', 'restaurant food', 'pan-frying', '{"total_weight_g":350.0,"iron_mg":4.42,"calcium_mg":197.0,"vitamin_C_mg":12.95}', '{"calories_kcal":800.0,"fat_g":30.0,"protein_g":25.0,"carbs_g":90.0}', '100g', '300g', '{"calories_kcal":250.0,"fat_g":10.0,"protein_g":5.0,"carbs_g":35.0}', 'stir-fried', '{"calories_kcal":600.0,"fat_g":20.0,"protein_g":25.0,"carbs_g":80.0}', '{"total_weight_g":250.0,"iron_mg":1.47,"calcium_mg":180.0,"vitamin_C_mg":19.5}', 'grilled meat salad', 'orange wafers']
# 100% 4/4 [01:21<00:00, 20.49s/it]
# 1
# 128
# 0.0078125

# %%
# !python -m src.finetune train
# Out:
# 2025-10-24 21:47:02.085342: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761342422.106394    4395 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761342422.112708    4395 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761342422.129205    4395 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761342422.129239    4395 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761342422.129244    4395 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761342422.129251    4395 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-24 21:47:02.134186: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !python -m src.finetune val vlm_model
# Out:
# 2025-04-17 00:19:49.852560: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744849189.929041   37373 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744849189.950454   37373 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-17 00:19:49.980595: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <frozen runpy>:128: RuntimeWarning: 'homework.finetune' found in sys.modules after import of package 'homework', but prior to execution of 'homework.finetune'; this may result in unpredictable behaviour
# Loaded 120 QA pairs for valid_grader split
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/peft/config.py", line 257, in _get_peft_type
#     config_file = hf_hub_download(
#                   ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py", line 106, in _inner_fn
#     validate_repo_id(arg_value)
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py", line 151, in validate_repo_id
#     raise HFValidationError(f"Repo id must be a string, not {type(repo_id)}: '{repo_id}'.")
# huggingface_hub.errors.HFValidationError: Repo id must be a string, not <class 'pathlib.PosixPath'>: '/content/drive/MyDrive/adl/adl-hw4/homework_04_v4/homework/vlm_model'.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/drive/MyDrive/adl/adl-hw4/homework_04_v4/homework/finetune.py", line 270, in <module>
#     Fire({"demo_train": demo_train, "train": train, "test": test_model})
#   File "/usr/local/lib/python3.11/dist-packages/fire/core.py", line 135, in Fire
#     component_trace = _Fire(component, args, parsed_flag_args, context, name)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/fire/core.py", line 468, in _Fire
#     component, remaining_args = _CallAndUpdateTrace(
#                                 ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/fire/core.py", line 684, in _CallAndUpdateTrace
#     component = fn(*varargs, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/adl/adl-hw4/homework_04_v4/homework/finetune.py", line 261, in test_model
#     llm = load(ckpt_path)
#           ^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/adl/adl-hw4/homework_04_v4/homework/finetune.py", line 27, in load
#     vlm.model = PeftModel.from_pretrained(vlm.model, model_path).to(vlm.device)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/peft/peft_model.py", line 479, in from_pretrained
#     PeftConfig._get_peft_type(
#   File "/usr/local/lib/python3.11/dist-packages/peft/config.py", line 263, in _get_peft_type
#     raise ValueError(f"Can't find '{CONFIG_NAME}' at '{model_id}'")
# ValueError: Can't find 'adapter_config.json' at '/content/drive/MyDrive/adl/adl-hw4/homework_04_v4/homework/vlm_model'

# %%
# !python -m src.finetune test vlm_model
# Out:
# __init__.py
# base_vlm.py
# data.py
# finetune.py
# generate_qa.py
# demo_train
# vlm_model
# demo_train/tensorboard
# demo_train/events.out.tfevents.1744847928.1a6f87ffe49c.31894.1
# demo_train/checkpoint-5
# demo_train/README.md
# demo_train/adapter_model.safetensors
# demo_train/adapter_config.json
# demo_train/training_args.bin
# demo_train/tensorboard/events.out.tfevents.1744847928.1a6f87ffe49c.31894.0
# demo_train/checkpoint-5/README.md
# demo_train/checkpoint-5/adapter_model.safetensors
# demo_train/checkpoint-5/adapter_config.json
# demo_train/checkpoint-5/training_args.bin
# demo_train/checkpoint-5/optimizer.pt
# demo_train/checkpoint-5/scheduler.pt
# demo_train/checkpoint-5/rng_state.pth
# demo_train/checkpoint-5/trainer_state.json
# vlm_model/tensorboard
# vlm_model/tensorboard/events.out.tfevents.1744848022.1a6f87ffe49c.32350.0
# Warning: The created zip file is larger than expected!
# Submission created: /content/drive/MyDrive/adl/adl-hw4/homework_04_v4/cbr2283.zip 49.36 MB

# %% [markdown]
# ---
