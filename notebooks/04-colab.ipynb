# %% [markdown]
# <a href="https://colab.research.google.com/github/chelseanbr/adl-hw4/blob/main/homework_04_v4/debug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Debug

# %% [markdown]
# https://colab.research.google.com/github/chelseanbr/adl-hw4/blob/main/debug.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://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@github.com/chelseanbr/adl-hw4.git
# Out:
# Cloning into 'adl-hw4'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 73 (delta 26), reused 41 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 73.75 KiB | 4.34 MiB/s, done.
# Resolving deltas: 100% (26/26), done.

# %%
# %cd /content/drive/MyDrive/adl/adl-hw4/homework_04_v4/
# %pwd
# %ls
# Out:
# /content/drive/MyDrive/adl/adl-hw4/homework_04_v4
# bundle.py  debug.ipynb  homework/           README.md         supertux_data.zip
# data/      grader/      homework_04_v4.zip  requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.7 MB/s eta 0:00:00
# ...

# %%
# !wget https://utexas.box.com/shared/static/qubjm5isldqvyimfj9rsmbnvnbezwcv4.zip -O supertux_data.zip
# !unzip supertux_data.zip

# %% [markdown]
# ---

# %%
# !git pull
# Out:
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 20 (delta 13), reused 14 (delta 8), pack-reused 0 (from 0)
# Unpacking objects: 100% (20/20), 287.75 KiB | 55.00 KiB/s, done.
# From https://github.com/chelseanbr/adl-hw4
#    cc51836..61a7244  main       -> origin/main
# Updating cc51836..61a7244
# Fast-forward
#  .gitignore                             |   4 +-
#  debug.ipynb                            | 706 +++++++++++++++++++++++++++++++++
#  homework_04_v4/debug.ipynb             | 353 +++++++++++++++--
#  homework_04_v4/homework/generate_qa.py | 216 +++++++---
#  4 files changed, 1180 insertions(+), 99 deletions(-)
#  create mode 100644 debug.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git config --global user.email "chelseanbr@utexas.edu"
# !git config --global user.name "Chelsea Ramos"
# !git add --all
# !git commit -m "update"
# !git push
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 345 bytes | 69.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/chelseanbr/adl-hw4.git
#    9b7c1da..99c9f3f  main -> main

# %% [markdown]
# ---

# %%
# !python -m homework.finetune demo_train
# Out:
# 2025-04-17 21:23:42.094607: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744925022.380723    3034 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744925022.455660    3034 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-17 21:23:43.067049: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python -m homework.finetune test demo_train
# Out:
# 2025-04-17 21:25:19.205904: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744925119.226183    3518 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744925119.232249    3518 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-17 21:25:19.253260: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python homework/generate_qa.py check --info_file ./data/valid/00000_info.json --view_index 0
# Out:
# python(49234) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Figure(1200x800)
#
# Question-Answer Pairs:
# --------------------------------------------------
# Q: What kart is the ego car?
# A: gnu
# --------------------------------------------------
# Q: How many karts are there in the scenario?
# A: 2
# --------------------------------------------------
# Q: What track is this?
# A: abyss
# --------------------------------------------------
# Q: Is beastie to the left or right of the ego car?
# A: right
# --------------------------------------------------
# Q: Is beastie in front of or behind the ego car?
# A: front
# --------------------------------------------------
# Q: How many karts are to the left of the ego car?
# A: 0
# --------------------------------------------------
# Q: How many karts are to the right of the ego car?
# A: 1
# --------------------------------------------------
# Q: How many karts are in front of the ego car?
# ...

# %%
# !python -m homework.finetune train
# Out:
# python(52433) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# <frozen runpy>:128: RuntimeWarning: 'homework.finetune' found in sys.modules after import of package 'homework', but prior to execution of 'homework.finetune'; this may result in unpredictable behaviour
# trainable params: 3,872,256 || all params: 260,357,184 || trainable%: 1.4873
# Loaded 428256 QA pairs for train split
# /opt/anaconda3/envs/advances_in_deeplearning/lib/python3.12/site-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8 (`cpuset` is not taken into account), which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ...

# %%
# !python -m homework.finetune test vlm_model
# Out:
# 2025-04-17 00:19:49.852560: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744849189.929041   37373 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744849189.950454   37373 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-17 00:19:49.980595: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python3 bundle.py homework cbr2283
# Out:
# __init__.py
# base_vlm.py
# data.py
# finetune.py
# generate_qa.py
# demo_train
# vlm_model
# demo_train/tensorboard
# demo_train/events.out.tfevents.1744847928.1a6f87ffe49c.31894.1
# demo_train/checkpoint-5
# demo_train/README.md
# demo_train/adapter_model.safetensors
# demo_train/adapter_config.json
# demo_train/training_args.bin
# demo_train/tensorboard/events.out.tfevents.1744847928.1a6f87ffe49c.31894.0
# demo_train/checkpoint-5/README.md
# demo_train/checkpoint-5/adapter_model.safetensors
# demo_train/checkpoint-5/adapter_config.json
# demo_train/checkpoint-5/training_args.bin
# demo_train/checkpoint-5/optimizer.pt
# demo_train/checkpoint-5/scheduler.pt
# demo_train/checkpoint-5/rng_state.pth
# demo_train/checkpoint-5/trainer_state.json
# vlm_model/tensorboard
# vlm_model/tensorboard/events.out.tfevents.1744848022.1a6f87ffe49c.32350.0
# ...
# Submission created: /content/drive/MyDrive/adl/adl-hw4/homework_04_v4/cbr2283.zip 49.36 MB

# %%
# !python3 -m grader cbr2283.zip
# Out:
# Val grader loaded.
# 2025-04-17 00:02:32.130180: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744848152.195982   32903 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744848152.229129   32903 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-17 00:02:32.292317: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %% [markdown]
# ---

# %%
# !python homework/generate_qa.py extract_karts --info_path ./data/valid/00000_info.json --view_index 0
# Out:
# {'track': 'abyss', 'karts': ['gnu', 'sara_the_racer', 'konqi', 'sara_the_wizard', 'beastie', 'suzanne', 'amanda', 'pidgin', 'xue', 'adiumy'], 'detections': [[[1, 0, 252, 146, 346, 239], [1, 4, 383, 162, 422, 193], [2, 0, 0, 155, 599, 399], [3, 0, 0, 0, 599, 399], [3, 97, 0, 0, 218, 150], [3, 101, 198, 17, 358, 150], [3, 103, 343, 98, 368, 147], [3, 113, 556, 106, 594, 148], [3, 115, 573, 123, 577, 131], [3, 117, 567, 112, 599, 141], [3, 119, 499, 113, 532, 149], [3, 121, 531, 113, 588, 146], [3, 123, 432, 106, 493, 149], [3, 242, 247, 45, 352, 147], [3, 243, 283, 87, 329, 128], [3, 245, 0, 0, 205, 149], [3, 246, 17, 34, 158, 144], [3, 248, 160, 11, 257, 86], [3, 249, 190, 42, 236, 82], [3, 251, 156, 76, 254, 146], [3, 252, 180, 94, 231, 143], [3, 254, 360, 69, 424, 112], [3, 255, 374, 77, 407, 110], [3, 374, 484, 6, 533, 149], [3, 378, 555, 57, 581, 114], [3, 380, 0, 3, 50, 150], [3, 384, 402, 8, 433, 149], [3, 386, 370, 59, 390, 149]], [[1, 0, 285, 149, 304, 166], [1, 1, 271, 171, 3
# ...

# %% [markdown]
# ```bash
#
# python homework/generate_qa.py extract_karts --info_path ./data/valid/000a0_info.json --view_index 1
#
# python homework/generate_qa.py extract_karts --info_path ./data/valid/000c2_info.json --view_index 6
#
# python homework/generate_qa.py extract_karts --info_path ./data/valid/000c2_info.json --view_index 1
#
# python homework/generate_qa.py extract_track --info_path ./data/valid/000c2_info.json
#
# python homework/generate_qa.py draw --image_path ./data/valid/000c2_06_im.jpg --info_path ./data/valid/000c2_info.json
#
# ```

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import homework.generate_qa as gqa
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
view = 6
image = f"./data/valid/000c2_0{view}_im.jpg"
info = './data/valid/000c2_info.json'

# kart_objs = gqa.extract_kart_objects(info, view)
# print(kart_objs)
# track_name = gqa.extract_track_info(info)
# print(track_name)
# qa_pairs = gqa.generate_qa_pairs(info, view)
# print(qa_pairs)
# drawing = gqa.draw_detections(
#     image,
#     info
#     )
# plt.imshow(drawing)

gqa.check_qa_pairs(info, view)
# Out:
# Question-Answer Pairs:
# --------------------------------------------------
# Q: What kart is the ego car?
# A: wilber
# --------------------------------------------------
# Q: How many karts are there in the scenario?
# A: 2
# --------------------------------------------------
# Q: What track is this?
# A: sandtrack
# --------------------------------------------------
# Q: Is xue to the left or right of the ego car?
# A: neither
# --------------------------------------------------
# Q: Is xue in front of or behind the ego car?
# A: behind
# --------------------------------------------------
# Q: How many karts are to the left of the ego car?
# A: 0
# --------------------------------------------------
# Q: How many karts are to the right of the ego car?
# A: 0
# --------------------------------------------------
# Q: How many karts are in front of the ego car?
# A: 0
# --------------------------------------------------
# Q: How many karts are behind the ego car?
# A: 1
# ...

# %%
view = 1
image = f"./data/valid/000c2_0{view}_im.jpg"
info = './data/valid/000c2_info.json'

# kart_objs = gqa.extract_kart_objects(info, view)
# print(kart_objs)
# track_name = gqa.extract_track_info(info)
# print(track_name)
# qa_pairs = gqa.generate_qa_pairs(info, view)
# print(qa_pairs)
# drawing = gqa.draw_detections(
#     image,
#     info
#     )
# plt.imshow(drawing)

gqa.check_qa_pairs(info, view)
# Out:
# Question-Answer Pairs:
# --------------------------------------------------
# Q: What kart is the ego car?
# A: xue
# --------------------------------------------------
# Q: How many karts are there in the scenario?
# A: 5
# --------------------------------------------------
# Q: What track is this?
# A: sandtrack
# --------------------------------------------------
# Q: Is amanda to the left or right of the ego car?
# A: right
# --------------------------------------------------
# Q: Is amanda in front of or behind the ego car?
# A: behind
# --------------------------------------------------
# Q: Is puffy to the left or right of the ego car?
# A: left
# --------------------------------------------------
# Q: Is puffy in front of or behind the ego car?
# A: behind
# --------------------------------------------------
# Q: Is gnu to the left or right of the ego car?
# A: right
# --------------------------------------------------
# Q: Is gnu in front of or behind the ego car?
# ...

# %%
view = 0
image = f"./data/valid/00000_0{view}_im.jpg"
info = './data/valid/00000_info.json'
gqa.check_qa_pairs(info, view)
# Out:
# Question-Answer Pairs:
# --------------------------------------------------
# Q: What kart is the ego car?
# A: gnu
# --------------------------------------------------
# Q: How many karts are there in the scenario?
# A: 2
# --------------------------------------------------
# Q: What track is this?
# A: abyss
# --------------------------------------------------
# Q: Is beastie to the left or right of the ego car?
# A: right
# --------------------------------------------------
# Q: Is beastie in front of or behind the ego car?
# A: front
# --------------------------------------------------
# Q: How many karts are to the left of the ego car?
# A: 0
# --------------------------------------------------
# Q: How many karts are to the right of the ego car?
# A: 1
# --------------------------------------------------
# Q: How many karts are in front of the ego car?
# A: 1
# --------------------------------------------------
# Q: How many karts are behind the ego car?
# A: 0
# ...

# %%
# !python homework/generate_qa.py generate_all --outfile all_qa_pairs.json
# Out:
# python(62713) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Generating all QA pairs for images in /Users/chelsearamos/Workspace/msai/spr25/adl/hw/adl-hw4/homework_04_v4/data/train...
# 100%|██████████████████████████████████████| 5250/5250 [00:15<00:00, 340.32it/s]

# %%
# !rm ./data/train/all_qa_pairs.json
# Out:
# python(57275) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
# !python homework/generate_qa.py generate_all
# Out:
# python(57288) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Generating all QA pairs for images in /Users/chelsearamos/Workspace/msai/spr25/adl/hw/adl-hw4/homework_04_v4/data/train...
# 100%|██████████████████████████████████████| 5250/5250 [00:16<00:00, 310.89it/s]

# %%
# !rm ./data/train/my_qa_pairs.json
# Out:
# python(57275) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
view = 2
image = f"./data/train/00638_0{view}_im.jpg"
info = './data/train/00638_info.json'
gqa.check_qa_pairs(info, view)
# Out:
# Question-Answer Pairs:
# --------------------------------------------------
# Q: What kart is the ego car?
# A: unknown
# --------------------------------------------------
# Q: How many karts are there in the scenario?
# A: 0
# --------------------------------------------------
# Q: What track is this?
# A: volcano_island
# --------------------------------------------------

# %%
# !python homework/generate_qa.py extract_tracks --info_path ./data/valid/00000_info.json --view_index 0
# Out:
# ERROR: Cannot find key: extract_tracks
# Usage: generate_qa.py <command>
#   available commands:    check | draw | extract_karts | extract_track | generate
#
# For detailed information on this command, run:
#   generate_qa.py --help

# %%
# !python homework/generate_qa.py generate --info_path ./data/valid/00000_info.json --view_index 0
# Out:
# Traceback (most recent call last):
#   File "/Users/chelsearamos/Workspace/msai/spr25/adl/hw/adl-hw4/homework_04_v4/homework/generate_qa.py", line 267, in <module>
#     main()
#   File "/Users/chelsearamos/Workspace/msai/spr25/adl/hw/adl-hw4/homework_04_v4/homework/generate_qa.py", line 260, in main
#     fire.Fire({"check": check_qa_pairs,
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/advances_in_deeplearning/lib/python3.12/site-packages/fire/core.py", line 135, in Fire
#     component_trace = _Fire(component, args, parsed_flag_args, context, name)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/advances_in_deeplearning/lib/python3.12/site-packages/fire/core.py", line 468, in _Fire
#     component, remaining_args = _CallAndUpdateTrace(
#                                 ^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !python homework/generate_qa.py check --info_file ./data/valid/00000_info.json --view_index 0
# Out:
# Figure(1200x800)
#
# Question-Answer Pairs:
# --------------------------------------------------
# Q: What kart is the ego car?
# A: gnu
# --------------------------------------------------
# Q: How many karts are there in the scenario?
# A: 2
# --------------------------------------------------
# Q: What track is this?
# A: abyss
# --------------------------------------------------
# Q: Is beastie to the left or right of the ego car?
# A: right
# --------------------------------------------------
# Q: Is beastie in front of or behind the ego car?
# A: front
# --------------------------------------------------
# Q: How many karts are to the left of the ego car?
# A: 0
# --------------------------------------------------
# Q: How many karts are to the right of the ego car?
# A: 1
# --------------------------------------------------
# Q: How many karts are in front of the ego car?
# A: 1
# --------------------------------------------------
# Q: How many karts are behind the ego car?
# ...
